# %% [markdown]
# ## 数据科学实践|Pandas篇

# %% [markdown]
# # 3.1 初级篇

# %%
import pandas as pd # 导入Pandas模块
raw_data = pd.read_excel("https://github.com/xiangyuchang/xiangyuchang.github.io/blob/master/BearData/shops_nm.xlsx?raw=true") #读入数据
print('数据的维度是：', raw_data.shape)
raw_data.head() #查看数据的前5行
# Out:
# 数据的维度是： (699, 9)
#               店名  ...                                                 菜名
# 0         老北京涮羊肉  ...  【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
# 1  鲜上鲜文鱼庄(望庭国际店)  ...  【菌菇大拼】【麻酱】【菠萝飞饼】【鸳鸯锅】【酸菜鸳鸯锅】【青菜】【毛肚】【文鱼】【菌汤】【鱼...
# 2    大龙燚火锅(李家村店)  ...  【手撕竹笋】【麻辣排骨】【砣砣牛肉】【菠萝飞饼】【鸭血】【四川金针菇】【麻辣牛肉】【贡菜】【...
# 3  鲜上鲜文鱼庄(阳阳国际店)  ...  【海带】【鸳鸯锅】【冻豆腐】【荷包豆腐】【生鱼片】【毛肚】【文鱼】【清汤锅】【山珍菌汤锅】【...
# 4     大龙燚火锅(粉巷店)  ...  【麻辣排骨】【千层毛肚】【鸳鸯锅】【鸭血】【天味香肠】【薄土豆】【功夫黄瓜】【清汤锅】【印度...
#
# [5 rows x 9 columns]

# %%
# 判断是否存在完全一致的数据行
duplicated_data = raw_data[raw_data.duplicated() == True]
if len(duplicated_data) == 0:
    print('不存在完全一致的数据行')
else:
    print(duplicated_data)
# Out:
# 不存在完全一致的数据行

# %%
print(raw_data.iloc[0,:])
raw_data.iloc[1,:] = raw_data.iloc[0,:]
# Out:
# 店名                                                 老北京涮羊肉
# 关键词                                                    火锅
# 城市                                                     xa
# 评分                                                    4.4
# 评价数                                                   877
# 人均                                                   45.5
# 地址               西安市雁塔区朱雀大街250号东方大酒店西门斜对面（子午路站下车向北走60米路西）
# 营业时间                                          11:00-21:00
# 菜名      【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
# Name: 0, dtype: object

# %%
# 判断是否存在完全一致的数据行
duplicated_data = raw_data[raw_data.duplicated() == True]
if len(duplicated_data) == 0:
    print('不存在完全一致的数据行')
else:
    print(duplicated_data)
# Out:
#        店名 关键词  ...         营业时间                                                 菜名
# 1  老北京涮羊肉  火锅  ...  11:00-21:00  【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
#
# [1 rows x 9 columns]

# %%
# 判断是否存在重复的店名
duplicated_shops = raw_data['店名'][raw_data['店名'].duplicated() == True]
if len(duplicated_shops) == 0:
    print('不存在重复的店名')
else:
    print(duplicated_shops)
# Out:
# 1    老北京涮羊肉
# Name: 店名, dtype: object

# %%
drop_duplicates_shops = raw_data.drop_duplicates(subset=['店名'])
drop_duplicates_shops.head()
# Out:
filter_words = ['人均：', '人均', '大概', '左右', '差不多'] #定义需要过滤的词
for i in range(len(raw_data2)):
    value = raw_data2['人均'].iloc[i] #取出人均这一行中的值
    if type(value) is int or type(value) is float: 
        continue #判断该值是否为整数或者浮点类型数字，如果满足则跳过进入下一步
    for word in filter_words:
        if word in value: #判断需要过滤的词是否在value中，如果在则去除
            raw_data2.loc[i, '人均'] = raw_data2.loc[i, '人均'].replace(word, '')

raw_data2.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#               店名  ...                                                 菜名
# 0         老北京涮羊肉  ...  【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
# 1         老北京涮羊肉  ...  【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
# 2    大龙燚火锅(李家村店)  ...  【手撕竹笋】【麻辣排骨】【砣砣牛肉】【菠萝飞饼】【鸭血】【四川金针菇】【麻辣牛肉】【贡菜】【...
# 3  鲜上鲜文鱼庄(阳阳国际店)  ...  【海带】【鸳鸯锅】【冻豆腐】【荷包豆腐】【生鱼片】【毛肚】【文鱼】【清汤锅】【山珍菌汤锅】【...
# 4     大龙燚火锅(粉巷店)  ...  【麻辣排骨】【千层毛肚】【鸳鸯锅】【鸭血】【天味香肠】【薄土豆】【功夫黄瓜】【清汤锅】【印度...
#
# [5 rows x 9 columns]

# %%
raw_data2.describe()
# Out:
#                评分          评价数
# count  695.000000   695.000000
# mean     4.024748   373.965468
# std      1.449025   930.503256
# min      0.000000     0.000000
# 25%      4.300000     5.000000
# 50%      4.500000    69.000000
# 75%      4.700000   301.500000
# max      5.000000  9417.000000

# %% [markdown]
# # 3.2 进阶篇

# %%
def clean_price(x):
    filter_words = ['人均：', '人均', '大概', '左右', '差不多']
    if type(x) is int or type(x) is float:
        return x 
    for word in filter_words:
        if word in value:
            x = x.replace(word, '')
    return x 

raw_data2['人均'] = raw_data2['人均'].apply(clean_price)
raw_data2['人均'] = raw_data2['人均'].astype(float)
raw_data2.head()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               店名 关键词  城市   评分     评价数     人均  \
# 0         老北京涮羊肉  火锅  xa  4.4   877.0   45.5
# 1  鲜上鲜文鱼庄(望庭国际店)  火锅  xa  4.6   535.0   56.0
# 2    大龙燚火锅(李家村店)  火锅  xa  4.6    29.0   92.0
# 3  鲜上鲜文鱼庄(阳阳国际店)  火锅  xa  4.6   906.0   56.0
# 4     大龙燚火锅(粉巷店)  火锅  xa  4.6  2253.0  100.0
#
#                                          地址               营业时间  \
# 0  西安市雁塔区朱雀大街250号东方大酒店西门斜对面（子午路站下车向北走60米路西）        11:00-21:00
# 1                 西安市高新区高新路80号望庭国际一栋楼10106室        11:00-23:00
# 2                西安市碑林区雁塔北路时亿广场南座2楼李家村华润万家外        10:00-22:00
# 3                  西安市雁塔区朱雀大街132号阳阳国际广场C座2楼        11:00-22:00
# 4                西安市碑林区粉巷南院门15A南苑中央广场食尚南苑2F  周一至周日 10:00-21:00
#
#                                                   菜名
# 0  【羊肉】【豆腐】【麻酱】【精品肥牛】【粉丝】【羔羊肉】【牛肚】【油豆皮】【香菇】【豆皮】【土...
# 1  【菌菇大拼】【麻酱】【菠萝飞饼】【鸳鸯锅】【酸菜鸳鸯锅】【青菜】【毛肚】【文鱼】【菌汤】【鱼...
# 2  【手撕竹笋】【麻辣排骨】【砣砣牛肉】【菠萝飞饼】【鸭血】【四川金针菇】【麻辣牛肉】【贡菜】【...
# 3  【海带】【鸳鸯锅】【冻豆腐】【荷包豆腐】【生鱼片】【毛肚】【文鱼】【清汤锅】【山珍菌汤锅】【...
# 4  【麻辣排骨】【千层毛肚】【鸳鸯锅】【鸭血】【天味香肠】【薄土豆】【功夫黄瓜】【清汤锅】【印度...

# %%
def cate_shops(x):
    if x <= 2:
        return 0
    if x > 2 and x <= 3.5:
        return 1
    if x > 3.5:
        return 2
    

raw_data2['商家等级'] = raw_data2['评分'].apply(cate_shops) #构建商家等级
raw_data2.groupby(by=['商家等级']).agg({'人均': 'mean'}) #根据商家等级分组，然后对于人均按照均值进行整合
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-079e63e5f1fa> in <module>()
#      10 group_rawdata = raw_data2.groupby(by=['商家等级'])
#      11 group_rawdata.head()
# ---> 12 group_rawdata['人均'].agg('pd.mean')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     758         _level = kwargs.pop('_level', None)
#     759         if isinstance(func_or_funcs, compat.string_types):
# --> 760             return getattr(self, func_or_funcs)(*args, **kwargs)
#     761
#     762         if isinstance(func_or_funcs, compat.Iterable):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'pd.mean'

# %%
coupon_data = pd.read_excel("https://github.com/xiangyuchang/xiangyuchang.github.io/blob/master/BearData/coupon_nm.xlsx?raw=true") #读入数据

#清洗数据，把没有评价的团购，购买人数为0的团购等去掉
coupon_data = coupon_data[coupon_data['团购评价'] != '暂无评价'][coupon_data['评价人数'] != '暂无评价']
coupon_data = coupon_data[coupon_data['购买人数'] != 0]
coupon_data = coupon_data.dropna()
coupon_data.head(2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                       团购名  ...                                               购买须知
# 3             396元1-15人服务  ...  【有效期2016年05月06日至2018年09月04日】\n【可用时间周末法定节假日通用24...
# 12  100元代金券！可使用包间，免费WiFi！  ...  【有效期2016年11月19日至2018年08月16日】\n【可用时间周末法定节假日通用11...
#
# [2 rows x 14 columns]

# %%
print(type(coupon_data['到期时间'].iloc[0])) #打印第一个团购的到期时间的数据类型
coupon_data['到期时间'] = pd.to_datetime(coupon_data['到期时间'], format='%Y-%m-%d') #转换团购到期时间为时间类型数据
print(type(coupon_data['到期时间'].iloc[0])) #重新查看第一个团购的到期时间的数据类型

from datetime import datetime # 字符串转化为时间类型
filter_coupon_data = coupon_data[coupon_data['到期时间'] > datetime.strptime('2018-09-01', '%Y-%m-%d')] #获得2018年9月1日后的团购
filter_coupon_data.head()
# Out:
# <class 'str'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#              团购名  ...                                               购买须知
# 3    396元1-15人服务  ...  【有效期2016年05月06日至2018年09月04日】\n【可用时间周末法定节假日通用24...
# 25   4人餐，免费WiFi！  ...  【有效期2017年04月12日至2019年07月12日】\n【可用时间周末法定节假日通用11...
# 26       100元代金券  ...  【有效期2017年04月21日至2020年01月29日】\n【可用时间周末法定节假日通用11...
# 27  五味缘100元晚餐代金券  ...  【有效期2018年01月29日至2019年01月30日】\n【可用时间周末法定节假日通用15...
# 28  小龙腾四海100元代金券  ...  【有效期2017年11月21日至2018年12月04日】\n【可用时间周末法定节假日通用11...
#
# [5 rows x 14 columns]

# %%
filter_coupon_data2 = filter_coupon_data.groupby('店名').agg({
    '团购价': 'mean',
    '购买人数': 'mean',
}) #按照店名分拆，用团购价与购买人数均值进行聚合
filter_coupon_data2.head(10)
# Out:
#                             团购价          购买人数
# 店名
# 2068香辣虾(巩义店)          85.000000   6638.000000
# 2068香辣虾(陕西总店)         86.000000  18784.000000
# 2306香辣虾时尚主题火锅(回郭镇店)  148.000000     12.000000
# IN聚乐时尚轰趴馆(青春店)       631.333333      4.000000
# 串串哆哆(西亚斯店)            10.200000    288.000000
# 丹东烤肉店(巩义店)            93.000000     45.500000
# 久味鲜斑鱼毛肚火锅(中心路店)       85.000000     35.000000
# 乐品自助餐烤肉+火锅            31.900000     36.000000
# 乡村地锅柴鸡               208.000000     62.000000
# 云鼎汇砂                 140.333333    271.666667

# %%
filter_coupon_data2['店名'] = filter_coupon_data2.index #添加新列’店名‘
filter_coupon_data2.index =  list(range(len(filter_coupon_data2))) #重新按照编号构建Index
filter_coupon_data2.head(10)
# Out:
#           团购价          购买人数                   店名
# 0   85.000000   6638.000000         2068香辣虾(巩义店)
# 1   86.000000  18784.000000        2068香辣虾(陕西总店)
# 2  148.000000     12.000000  2306香辣虾时尚主题火锅(回郭镇店)
# 3  631.333333      4.000000       IN聚乐时尚轰趴馆(青春店)
# 4   10.200000    288.000000           串串哆哆(西亚斯店)
# 5   93.000000     45.500000           丹东烤肉店(巩义店)
# 6   85.000000     35.000000      久味鲜斑鱼毛肚火锅(中心路店)
# 7   31.900000     36.000000           乐品自助餐烤肉+火锅
# 8  208.000000     62.000000               乡村地锅柴鸡
# 9  140.333333    271.666667                 云鼎汇砂

# %%
merge_data = pd.merge(left=raw_data2, right=filter_coupon_data2, on='店名', how='inner') #按照店名合并
merge_data['购买人数'] = merge_data['购买人数'].astype(int) #转化为整数
print(merge_data.shape)

merge_data.head()
# Out:
# (198, 12)
#                   店名 关键词  城市  ...  商家等级    团购价   购买人数
# 0             老北京涮羊肉  火锅  xa  ...     2  118.5   1692
# 1             老北京涮羊肉  火锅  xa  ...     2  118.5   1692
# 2         大龙燚火锅(粉巷店)  火锅  xa  ...     2   88.0  19584
# 3      鲜上鲜文鱼庄(凤城五路店)  火锅  xa  ...     2   52.0  11798
# 4  蜜悦士鲜牛肉时尚火锅(凯德广场店)  火锅  xa  ...     2   59.9     40
#
# [5 rows x 12 columns]

# %%
merge_data.to_excel(os.path.join(path, 'merge_shop_coupon_nm.xlsx'), encoding='utf8', index=False)
