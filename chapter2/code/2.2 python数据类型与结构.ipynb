# %% [markdown]
# ### 1.基本数据类型

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\qian\\Desktop\\5、写书的资料\\cluebearpython-master(1)\\cluebearpython-master\\data')
os.getcwd()
# Out:
# 'C:\\Users\\qian\\Desktop\\5、写书的资料\\cluebearpython-master(1)\\cluebearpython-master\\data'

# %%
import pandas as pd
coupon=pd.read_excel("coupon_nm.xlsx")
coupon.head()
# Out:
#              团购名                 店名    团购活动ID  \
# 0   壹分之贰豪华生日派对套餐  壹分之贰聚会吧桌游轰趴馆(旗舰店)  38744470
# 1     壹分之贰豪华棋牌包间  壹分之贰聚会吧桌游轰趴馆(旗舰店)  38632123
# 2   壹分之贰豪华生日派对套餐  壹分之贰聚会吧桌游轰趴馆(旗舰店)  38744514
# 3    396元1-15人服务  壹分之贰聚会吧桌游轰趴馆(旗舰店)  13377118
# 4  六婆串串香火锅100代金券            六婆串串香火锅  38767590
#
#                                                 团购介绍  购买人数  团购评价  评价人数  \
# 0  仅售880元，价值7342元豪华生日派对聚会桌游轰趴夜场10小时（通宵包场）！免费WiFi，...     0  暂无评价  暂无评价
# 1              仅售98元，价值240元豪华棋牌包间4小时套餐（4人）1份！免费WiFi！     0  暂无评价  暂无评价
# 2      仅售480元，价值3685元豪华生日派对聚会桌游轰趴5小时（包场）！免费WiFi，需预约！     0  暂无评价  暂无评价
# 3                   仅售396元，价值2575元台球优享套餐！免费WiFi，需预约！     8     5     3
# 4                       仅售85元，价值100元代金券！免费停车，免费WiFi！     6  暂无评价  暂无评价
#
#          到期时间    团购价     市场价                                           地址  \
# 0  2018-08-10    NaN     NaN                  【西安市雁塔区小寨东路11号壹又贰分之壹B楼1003】
# 1  2018-08-10    NaN     NaN                  【西安市雁塔区小寨东路11号壹又贰分之壹B楼1003】
# ...

# %%
coupon.iloc[0,2]==coupon.iloc[2,2]
# Out:
# False

# %%
coupon['店名']=='六婆串串香火锅'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1825    False
# 1826    False
# 1827    False
# 1828    False
# 1829    False
# 1830    False
# 1831    False
# 1832    False
# 1833    False
# 1834    False
# 1835    False
# 1836    False
# 1837    False
# 1838    False
# 1839    False
# 1840    False
# 1841    False
# 1842    False
# 1843    False
# 1844    False
# 1845    False
# 1846    False
# 1847    False
# 1848    False
# 1849    False
# 1850    False
# 1851    False
# 1852    False
# 1853    False
# 1854    False
# ...

# %%
coupon[coupon['店名']=='六婆串串香火锅']
# Out:
#              团购名       店名    团购活动ID                          团购介绍  购买人数  团购评价  \
# 4  六婆串串香火锅100代金券  六婆串串香火锅  38767590  仅售85元，价值100元代金券！免费停车，免费WiFi！     6  暂无评价
#
#    评价人数        到期时间   团购价    市场价                                           地址  \
# 4  暂无评价  2018-08-30  85.0  100.0  【西安市雁塔区长丰园小区12号楼7号商铺】【西安市周至县中心街隆发云塔广场C016号】
#
#                           团购内容   备注  \
# 4  【内容: 代金券, 规格: 1张, 价格: 100元】  随便退
#
#                                                 购买须知
# 4  【有效期2017年06月09日至2018年08月30日】\n【可用时间周末法定节假日通用09...

# %%
coupon.dtypes
# Out:
# 团购名        object
# 店名         object
# 团购活动ID      int64
# 团购介绍       object
# 购买人数        int64
# 团购评价       object
# 评价人数       object
# 到期时间       object
# 团购价       float64
# 市场价       float64
# 地址         object
# 团购内容       object
# 备注         object
# 购买须知       object
# dtype: object

# %%
type(16.9)
# Out:
# float

# %%
type(4/5)
# Out:
# float

# %%
12.3+4j
12.3+4*j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-71eae31e3da3> in <module>()
#       1 12.3+4j
# ----> 2 12.3+4*j
#
# NameError: name 'j' is not defined

# %%
(3+1j).real
(3+1j).imag
# Out:
# 1.0

# %%
type('六婆串串香火锅')
# Out:
# str

# %%
name='六婆串串香火锅'
name*3
# Out:
# '六婆串串香火锅六婆串串香火锅六婆串串香火锅'

# %%
'六婆' in name
# Out:
# True

# %%
name[0]
# Out:
# '六'

# %%
name[2:4]
# Out:
# '串串'

# %%
len(name)
# Out:
# 7

# %%
ID=coupon.loc[0,'团购活动ID']
type(ID)
IDNEW=str(ID)
IDNEW
# Out:
# '38744470'

# %%
coupon['到期时间'].dtypes
# Out:
# dtype('O')

# %%
coupon['到期时间']=pd.to_datetime(coupon['到期时间'])
coupon['到期时间'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
year1=[i.year for i in coupon['到期时间']]
month1=[i.month for i in coupon['到期时间']]
day1=[i.day for i in coupon['到期时间']]
weekday1=[i.weekday_name for i in coupon['到期时间']]
# Out:
# C:\Users\qian\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   after removing the cwd from sys.path.

# %%
year1
# Out:
# [2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2019,
#  2019,
#  2020,
#  2019,
#  2018,
#  2019,
#  2019,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
# ...

# %%
month1
# Out:
# [8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  8,
#  9,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  6,
#  7,
#  7,
#  1,
#  1,
#  12,
#  2,
#  2,
#  2,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  12,
#  10,
#  9,
#  10,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  2,
#  2,
#  2,
#  2,
#  2,
#  8,
#  8,
#  8,
#  9,
#  8,
#  8,
#  3,
#  3,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  1,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  9,
#  8,
#  1,
#  8,
#  8,
#  9,
#  8,
#  9,
#  8,
#  8,
#  9,
#  9,
#  8,
#  8,
#  8,
#  1,
#  1,
#  1,
#  1,
#  8,
#  8,
#  8,
#  1,
#  1,
#  8,
#  9,
#  9,
#  9,
#  1,
#  1,
#  1,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  12,
#  12,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  9,
# ...

# %%
coupon['到期时间'][0]
# Out:
# Timestamp('2018-08-10 00:00:00')

# %%
coupon.iloc[1,]
# Out:
# 团购名                                              壹分之贰豪华棋牌包间
# 店名                                        壹分之贰聚会吧桌游轰趴馆(旗舰店)
# 团购活动ID                                             38632123
# 团购介绍                  仅售98元，价值240元豪华棋牌包间4小时套餐（4人）1份！免费WiFi！
# 购买人数                                                      0
# 团购评价                                                   暂无评价
# 评价人数                                                   暂无评价
# 到期时间                                    2018-08-10 00:00:00
# 团购价                                                     NaN
# 市场价                                                     NaN
# 地址                              【西安市雁塔区小寨东路11号壹又贰分之壹B楼1003】
# 团购内容                【内容: 豪华棋牌包间4小时套餐（4人）, 规格: 1份, 价格: 240元】
# 备注                                                      随便退
# 购买须知      【有效期2017年05月26日至2018年08月10日】\n【可用时间周末法定节假日通用08...
# Name: 1, dtype: object

# %%
coupon['到期时间'][0].year
# Out:
# 2018

# %%
coupon['到期时间'][0].month
# Out:
# 8

# %%
coupon['到期时间'][0].day
# Out:
# 10

# %%
import time
print(time.time())
# Out:
# 1548326800.6374881

# %%
print(time.localtime(time.time()))
print(time.asctime(time.localtime(time.time())))
# Out:
# time.struct_time(tm_year=2019, tm_mon=1, tm_mday=24, tm_hour=18, tm_min=46, tm_sec=48, tm_wday=3, tm_yday=24, tm_isdst=0)
# Thu Jan 24 18:46:48 2019

# %%
print(time.strftime('%Y-%m-%d %H:%M:%S',time.localtime()))
# Out:
# 2019-01-24 18:46:57

# %%
import datetime#导入模块datetime
datetime.datetime.now()#获取当前时间
t1=datetime.datetime(2018, 11, 11, 11, 1, 29, 738212)#自定义时间
t1
t2=datetime.datetime.now()
t2
sub=t2-t1 #时间相减
sub.seconds #时间相差秒数
t2.year#时间中的年
t2.month#时间中的月
t2.day#时间中的日
t2.hour#时间中的小时
t2.minute#时间中的分钟
t2.second#时间中的秒
# Out:
# 10

# %% [markdown]
# ### 2.基本数据结构

# %%
list0=[]
list1=['团购名','店名','团购活动ID','团购介绍','购买人数','团购评价','评价人数','地址','团购内容']
list2=['13377118','8','随便退']
list3=['壹分之贰聚会吧桌游轰趴馆(旗舰店)',list2]

# %%
type(list1)
# Out:
# list

# %%
list1=['团购名','店名','团购活动ID','团购介绍','购买人数','团购评价','评价人数','地址','团购内容']
list4=['到期时间','团购价','市场价','备注','购买须知']
list5=list1+list4

# %%
len(list5)
# Out:
# 14

# %%
'团购活动ID'in list5
'客户名'in list5
# Out:
# False

# %%
list5[0]
list5[2:7]
# Out:
# ['团购活动ID', '团购介绍', '购买人数', '团购评价', '评价人数']

# %%
for i in list5:
  print(i)
# Out:
# 团购名
# 店名
# 团购活动ID
# 团购介绍
# 购买人数
# 团购评价
# 评价人数
# 地址
# 团购内容
# 到期时间
# 团购价
# 市场价
# 备注
# 购买须知

# %%
del list5[0]
list5
del list5
list5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-f43b1ffef323> in <module>()
#       2 list5
#       3 del list5
# ----> 4 list5
#
# NameError: name 'list5' is not defined

# %%
list4=['到期时间','团购价','市场价','备注','购买须知']
list4.append('团购名')
list4.insert(0,'店名')
list4.append('团购名')
list4.count('团购名')
# Out:
# 2

# %%
tuple0=()
tuple1=(2,4,5)
tuple2=('a','b','c')
tuple3=(21,'a','c')

# %%
tuple2[1]
tuple2[0:3]
# Out:
# ('a', 'b', 'c')

# %%
tuple2[2]=4
tuple4=tuple2+tuple3
tuple5=tuple4[2:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-83b582aa3595> in <module>()
# ----> 1 tuple2[2]=4
#       2 tuple4=tuple2+tuple3
#       3 tuple5=tuple4[2:5]
#
# TypeError: 'tuple' object does not support item assignment

# %%
dict0={'六婆串串香火锅':6,'嗲串串':14}
type(dict0)
# Out:
# dict

# %%
dict0['嗲串串']
dict0['古城串串']=0
dict0['古城串串']=2
del dict0['古城串串']
dict0
# Out:
# {'六婆串串香火锅': 6, '嗲串串': 14}

# %%
dict0.keys()
dict0.values()
dict0.items()
dict0.get('嗲串串')
# Out:
# 14

# %%
set1={1,2,'s',1,1,1}
type(set1)
set2=set([1,3,4,5])
set3=set((1,3,'e'))
set4=set('python')

# %%
A={1,2,3}
B={3,4,5}
A-B##差集
A|B##并集
A&B##交集
# Out:
# {3}

# %%
set1={'古城串串','嗲串串','六婆串串香火锅'}
set1.add('天天鲜羊肉馆')
set1.remove('天天鲜羊肉馆')
set1.clear()
