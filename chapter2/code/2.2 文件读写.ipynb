# %%
f = open("food.txt", "w")
f.write("西安火锅真棒。\n我喜欢西安的火锅!!\n")
f.close()

# %%
f = open("food.txt", "r")

str = f.read(4)

print(str)

f.close()
# Out:
# 西安火锅

# %%
f = open("food.txt", "r")
str = f.readline()
print(str)
f.close()
# Out:
# 西安火锅真棒。

# %%
f = open("火锅.txt", "r")
str = f.readline()
print(str)
f.close()
# Out:
# 【内容: 豪华主题场地, 规格: 10小时, 价格: 600元】

# %%
f = open("food.txt", "r")
a = f.readlines()
print(a)
f.close()
# Out:
# ['西安火锅真棒。\n', '我喜欢西安的火锅!!\n']

# %%
f = open("火锅.txt", "r")
a = f.readlines()
print(a)
f.close()
# Out:
# ['【内容: 豪华主题场地, 规格: 10小时, 价格: 600元】\n', '【内容: 轰趴场地布置, 规格: 10小时, 价格: 600元】\n', '【内容: 私人自助厨房, 规格: 10小时, 价格: 400元】\n', '【内容: 自助火锅（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助烧烤（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助烹饪（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助调酒（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 美式桌球, 规格: 10小时, 价格: 200元】\n', '【内容: 美式桌上足球, 规格: 10小时, 价格: 200元】\n', '【内容: 桌面冰壶, 规格: 10小时, 价格: 200元】\n', '【内容: 乒乓球娱乐, 规格: 10小时, 价格: 200元】\n', '【内容: 50寸KTV液晶显示器, 规格: 10小时, 价格: 100元】\n', '【内容: KTV豪华包房, 规格: 10小时, 价格: 300元】\n', '【内容: 自动棋牌（包间）, 规格: 10小时, 价格: 300元】\n', '【内容: X-box体感游戏, 规格: 10小时, 价格: 300元】\n', '【内容: X-box手柄游戏, 规格: 10小时, 价格: 200元】\n', '【内容: VR虚拟现实体验, 规格: 10小时, 价格: 200元】\n', '【内容: VR虚拟射击体验, 规格: 10小时, 价格: 200元】\n', '【内容: 42游戏液晶显示器, 规格: 10小时, 价格: 100元】\n', '【内容: 小霸王游戏机, 规格: 10小时, 价格: 100元】\n', '【内容: 桌游畅玩, 规格: 10小时, 价格: 750元】\n', '【内容: 小丑服饰装扮, 规格: 10小时, 价格: 200元】\n', '【内容: 桌游主持讲解, 规格: 10小时, 价格: 200元】\n', '【内容: 百兆光纤WIFi, 规格: 10小时, 价格: 100元】\n', '【内容: 120寸高清投影, 规格: 10小时, 价格: 200元】\n', '【内容: 大厅3D环绕音效, 规格: 1
# ...

# %%
f = open("food.txt", "r")
a = f.readlines()
print(a)
f.close()

# %%
f = open("火锅.txt", "r")
a = f.readlines()
print(a)
f.close()
# Out:
# ['【内容: 豪华主题场地, 规格: 10小时, 价格: 600元】\n', '【内容: 轰趴场地布置, 规格: 10小时, 价格: 600元】\n', '【内容: 私人自助厨房, 规格: 10小时, 价格: 400元】\n', '【内容: 自助火锅（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助烧烤（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助烹饪（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 自助调酒（设备）, 规格: 10小时, 价格: 100元】\n', '【内容: 美式桌球, 规格: 10小时, 价格: 200元】\n', '【内容: 美式桌上足球, 规格: 10小时, 价格: 200元】\n', '【内容: 桌面冰壶, 规格: 10小时, 价格: 200元】\n', '【内容: 乒乓球娱乐, 规格: 10小时, 价格: 200元】\n', '【内容: 50寸KTV液晶显示器, 规格: 10小时, 价格: 100元】\n', '【内容: KTV豪华包房, 规格: 10小时, 价格: 300元】\n', '【内容: 自动棋牌（包间）, 规格: 10小时, 价格: 300元】\n', '【内容: X-box体感游戏, 规格: 10小时, 价格: 300元】\n', '【内容: X-box手柄游戏, 规格: 10小时, 价格: 200元】\n', '【内容: VR虚拟现实体验, 规格: 10小时, 价格: 200元】\n', '【内容: VR虚拟射击体验, 规格: 10小时, 价格: 200元】\n', '【内容: 42游戏液晶显示器, 规格: 10小时, 价格: 100元】\n', '【内容: 小霸王游戏机, 规格: 10小时, 价格: 100元】\n', '【内容: 桌游畅玩, 规格: 10小时, 价格: 750元】\n', '【内容: 小丑服饰装扮, 规格: 10小时, 价格: 200元】\n', '【内容: 桌游主持讲解, 规格: 10小时, 价格: 200元】\n', '【内容: 百兆光纤WIFi, 规格: 10小时, 价格: 100元】\n', '【内容: 120寸高清投影, 规格: 10小时, 价格: 200元】\n', '【内容: 大厅3D环绕音效, 规格: 1
# ...

# %%
file = open('food.txt', 'r')
for line in file:
    print (line)
# Out:
# 西安火锅真棒。
#
# 我喜欢西安的火锅!!

# %%
file = open('火锅.txt', 'r')
for line in file:
    print (line)
# Out:
# 【内容: 豪华主题场地, 规格: 10小时, 价格: 600元】
#
# 【内容: 轰趴场地布置, 规格: 10小时, 价格: 600元】
#
# 【内容: 私人自助厨房, 规格: 10小时, 价格: 400元】
#
# 【内容: 自助火锅（设备）, 规格: 10小时, 价格: 100元】
#
# 【内容: 自助烧烤（设备）, 规格: 10小时, 价格: 100元】
#
# 【内容: 自助烹饪（设备）, 规格: 10小时, 价格: 100元】
#
# 【内容: 自助调酒（设备）, 规格: 10小时, 价格: 100元】
#
# 【内容: 美式桌球, 规格: 10小时, 价格: 200元】
#
# 【内容: 美式桌上足球, 规格: 10小时, 价格: 200元】
#
# 【内容: 桌面冰壶, 规格: 10小时, 价格: 200元】
#
# 【内容: 乒乓球娱乐, 规格: 10小时, 价格: 200元】
#
# 【内容: 50寸KTV液晶显示器, 规格: 10小时, 价格: 100元】
#
# 【内容: KTV豪华包房, 规格: 10小时, 价格: 300元】
#
# 【内容: 自动棋牌（包间）, 规格: 10小时, 价格: 300元】
#
# 【内容: X-box体感游戏, 规格: 10小时, 价格: 300元】
#
# 【内容: X-box手柄游戏, 规格: 10小时, 价格: 200元】
#
# 【内容: VR虚拟现实体验, 规格: 10小时, 价格: 200元】
#
# 【内容: VR虚拟射击体验, 规格: 10小时, 价格: 200元】
#
# 【内容: 42游戏液晶显示器, 规格: 10小时, 价格: 100元】
#
# 【内容: 小霸王游戏机, 规格: 10小时, 价格: 100元】
#
# 【内容: 桌游畅玩, 规格: 10小时, 价格: 750元】
#
# 【内容: 小丑服饰装扮, 规格: 10小时, 价格: 200元】
#
# 【内容: 桌游主持讲解, 规格: 10小时, 价格: 200元】
#
# 【内容: 百兆光纤WIFi, 规格: 10小时, 价格: 100元】
#
# 【内容: 120寸高清投影, 规格: 10小时, 价格: 200元】
#
# 【内容: 大厅3D环绕音效, 规格: 10小时, 价格: 160元】
#
# ...

# %%
file = open("火锅团购.txt", "w")
file.write("西安火锅团购大促销")
file.write("西安火锅哪家强")
file.close()
